# %%
import seaborn as syn
import matplotlib.pyplot as plt

# %%
years=[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019]
kohli=[250,400,550,700,900,1500,2200,2800,4500,8000]

syn.barplot(kohli)
# Out:
# <Axes: >

# %%
syn.lineplot(kohli)
# Out:
# <Axes: >

# %%
syn.lineplot(years)
# Out:
# <Axes: >
